# %%
from sklearn import datasets
# Out:
# -----------------------------------------------------------------
# ImportError                     Traceback (most recent call last)
# <ipython-input-1-6220872a2123> in <module>
# ----> 1 from sklearn import datasets
#
# c:\program files (x86)\python37-32\lib\site-packages\sklearn\__init__.py in <module>
#      74 else:
#      75     from . import __check_build
# ---> 76     from .base import clone
#      77     from .utils._show_versions import show_versions
#      78
#
# c:\program files (x86)\python37-32\lib\site-packages\sklearn\base.py in <module>
#      14
#      15 from . import __version__
# ---> 16 from .utils import _IS_32BIT
#      17
#      18 _DEFAULT_TAGS = {
#
# c:\program files (x86)\python37-32\lib\site-packages\sklearn\utils\__init__.py in <module>
#      18 from ..exceptions import DataConversionWarning
#      19 from .deprecation import deprecated
# ---> 20 from .validation import (as_float_array,
#      21                          assert_all_finite,
# ...
